# %% [markdown]
# **Theory
# Questions**

# %%
'''1. What is the difference between interpreted and compiled languages?
Interpreted: Executes code line-by-line (Python, JavaScript).

Compiled: Converts code to machine code before execution (C, C++).'''

# %%
'''2. What is exception handling in Python?
A mechanism to handle runtime errors using try, except, else, and finally.'''

# %%
'''3. Purpose of finally block in exception handling?
Runs always (with or without error). Used for cleanup (closing files, releasing resources).'''

# %%
'''4. What is logging in Python?
Recording program information, warnings, and errors into console or files.'''

# %%
'''5. Significance of del method in Python?
Destructor method called when an object is deleted or goes out of scope.'''

# %%
'''6. Difference between import and from ... import
import module → use module.function()

from module import function → directly use function().'''

# %%
'''7. How can you handle multiple exceptions in Python?
Using:

except (TypeError, ValueError):

OR multiple except blocks.'''

# %%
'''8. Purpose of with statement in file handling
Automatically opens and closes files safely, even during errors.'''

# %%
'''9. Difference between multithreading and multiprocessing
Multithreading: Multiple threads share the same memory.

Multiprocessing: Each process has its own memory.'''

# %%
'''10. vantages of using logging
Helps in debugging

Records errors

Provides runtime monitoring

Maintains logs for future reference.'''

# %%
'''11. What is memory management in Python?
Automatic allocation & deallocation of memory using Garbage Collection + Reference Counting.'''

# %%
'''12. Steps involved in exception handling
Code at risk → try

Error handler → except

Run when no error → else

Cleanup → finally.'''

# %%
'''13. Why is memory management important?
Prevents memory leaks and improves performance.'''

# %%
'''14. Role of try and except
try: Code that may cause error

except: Handles the error safely.'''

# %%
'''15. How Python’s garbage collector works?
Removes unreferenced objects using:

Reference counting

Cyclic garbage collector.'''

# %%
'''16. Purpose of else block
Runs only if no exception occurs.'''

# %%
'''17. Common logging levels
DEBUG, INFO, WARNING, ERROR, CRITICAL.'''

# %%
'''18. Difference between os.fork() and multiprocessing
os.fork() → Unix-only process duplication

multiprocessing → Cross-platform process creation module.'''

# %%
'''19. Importance of closing a file
Releases memory, prevents data loss and file corruption.'''

# %%
'''20. Difference between file.read() and file.readline()
read() → entire file

readline() → only one line.'''

# %%
'''21. What is the logging module used for?
To store logs of events, errors, and information.'''

# %%
'''22. What is the os module used for in file handling?
File path operations: checking existence, listing, deleting files, directories.'''

# %%
'''23. Challenges with memory management in Python
Cyclic references

Large object memory usage

Delayed garbage collection.'''

# %%
'''24. How do you raise an exception manually?
raise Exception("Custom error").'''

# %%
'''25. Why use multithreading?

Useful for:

Background tasks

I/O operations

Faster task switching.'''

# %% [markdown]
# ****Practical Answers****

# %%
#1. How can you open a file for writing in Python and write a string to it?

with open("demo.txt", "w") as f:
    f.write("Hello, this is a Python file.")

# %%
#2. Write a Python program to read the contents of a file and print each line.

with open("demo.txt", "r") as f:
    for line in f:
        print(line)
# Out:
# Hello, this is a Python file.

# %%
#3. How would you handle a case where the file doesn’t exist while trying to open it for reading?

try:
    f = open("missing.txt", "r")
except FileNotFoundError:
    print("File does not exist!")
# Out:
# File does not exist!

# %%
#4. Write a Python script that reads from one file and writes its content to another file.

# Create a sample source file
with open("source.txt", "w") as f:
    f.write("This is sample content for testing file copy.")

# %%
with open("source.txt", "r") as s, open("destination.txt", "w") as d:
    d.write(s.read())

print("File copied successfully!")
# Out:
# File copied successfully!

# %%
#5. How would you catch and handle division by zero error in Python?

try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")
# Out:
# Cannot divide by zero!

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))
    result = a / b
    print("Result:", result)

except ZeroDivisionError:
    logging.error("Division by zero occurred.")
    print("Error: Cannot divide by zero! (Logged in error.log)")
# Out:
# Enter a number: 12
# Enter another number: 45
# Result: 0.26666666666666666

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) using logging module?

import logging
logging.basicConfig(level=logging.INFO)

logging.info("This is an info message")
logging.warning("This is a warning")
logging.error("This is an error message")
# Out:
# WARNING:root:This is a warning
# ERROR:root:This is an error message

# %%
#8. Write a program to handle file opening error using exception handling.

try:
    f = open("unknown.txt")
except Exception as e:
    print("Handled:", e)
# Out:
# Handled: [Errno 2] No such file or directory: 'unknown.txt'

# %%
#9. How can you read a file line by line and store its content in a list in Python?
lines = []
with open("demo.txt") as f:
    lines = f.readlines()

print(lines)
# Out:
# ['Hello, this is a Python file.']

# %%
#10. How can you append data to an existing file in Python?

with open("demo.txt", "a") as f:
    f.write("\nThis is a new appended line.")

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn’t exist.

data = {"name": "Shreya"}

try:
    print(data["age"])
except KeyError:
    print("Key does not exist!")
# Out:
# Key does not exist!

# %%
#12. Write a program with multiple except blocks to handle different types of exceptions.

try:
    num = int("abc")
except ValueError:
    print("ValueError occurred")
except TypeError:
    print("TypeError occurred")
# Out:
# ValueError occurred

# %%
#13. How would you check if a file exists before attempting to read it in Python?

import os

if os.path.exists("demo.txt"):
    print("File exists")
else:
    print("File does not exist")
# Out:
# File exists

# %%
#14. Write a program that uses the logging module to log both informational and error messages.

import logging

logging.basicConfig(filename="events.log", level=logging.INFO)

logging.info("Program started")

try:
    x = 10 / 0
except ZeroDivisionError as e:
    logging.error("Error occurred: %s", e)
    print("Logged the error in events.log")
# Out:
# ERROR:root:Error occurred: division by zero
# Logged the error in events.log

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty.

try:
    with open("demo.txt") as f:
        content = f.read()
        if content == "":
            print("File is empty")
        else:
            print(content)
except FileNotFoundError:
    print("File not found")

# %% [markdown]
# Hello, this is a Python file.
# This is a new appended line.

# %%
#16. Demonstrate how to use memory profiling to check memory usage of a small program.
#Note: Real profiler requires installation (memory_profiler) → sample code:

import sys

list1 = list(range(1000))
print("Memory used:", sys.getsizeof(list1), "bytes")
# Out:
# Memory used: 8056 bytes

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line.

numbers = [10, 20, 30, 40, 50]

with open("numbers.txt", "w") as f:
    for n in numbers:
        f.write(str(n) + "\n")

# %%
#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("mylog.log", maxBytes=1*1024*1024, backupCount=2)
logging.basicConfig(handlers=[handler], level=logging.INFO)

logging.info("Log rotation started")

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block.

try:
    arr = [1, 2, 3]
    print(arr[5])

    data = {"name": "Shreya"}
    print(data["age"])
except IndexError:
    print("IndexError occurred")
except KeyError:
    print("KeyError occurred")
# Out:
# IndexError occurred

# %%
#20. How would you open a file and read its contents using a context manager in Python?

with open("demo.txt", "r") as f:
    print(f.read())

# %% [markdown]
# Hello, this is a Python file.
# This is a new appended line.

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

word = "python"

with open("demo.txt", "r") as f:
    text = f.read().lower()

print("Occurrences:", text.count(word))

# %% [markdown]
# Occurrences: 1

# %%
#22. How can you check if a file is empty before attempting to read its contents?

import os

size = os.path.getsize("demo.txt")

if size == 0:
    print("File is empty")
else:
    print("File is not empty")
# Out:
# File is not empty

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling.

import logging

# Configure logging
logging.basicConfig(filename="file_error.log",
                    level=logging.ERROR,
                    format="%(levelname)s:%(message)s")

try:

    with open("not_found.txt", "r") as f:
        data = f.read()

except FileNotFoundError as e:
    logging.error(f"File handling error: {e}")
# Out:
# ERROR:root:File handling error: [Errno 2] No such file or directory: 'not_found.txt'
